# %%
import pandas as pd

df = pd.read_csv('./dataset/rec_facilities.csv')
df

# %%
import pandas as pd

final_df = pd.read_csv('final_data/recreation_data.csv')
final_df
# Out:
#                                 COMPLEX_NAME FACILITY_TYPE  \
# 0                       Carrington Skatepark    Skate Park
# 1                          Ernie Starr Arena         Arena
# 2                          Ernie Starr Arena         Arena
# 3                          Ernie Starr Arena         Arena
# 4                          Ernie Starr Arena         Arena
# ...                                      ...           ...
# 4713  Forest Lawn Outdoor Pool & Wading Pool  Outdoor Pool
# 4714  Forest Lawn Outdoor Pool & Wading Pool  Outdoor Pool
# 4715  Forest Lawn Outdoor Pool & Wading Pool  Outdoor Pool
# 4716  Forest Lawn Outdoor Pool & Wading Pool  Outdoor Pool
# 4717  Forest Lawn Outdoor Pool & Wading Pool  Outdoor Pool
#
#                   ADDRESS      TYP_OF_ORG         ORG     STEWARD        OPER  \
# 0     37 CARRINGTON PZ NW       Municipal       Parks       Parks       Parks
# 1           4808 14 AV SE       Municipal  Recreation  Recreation  Recreation
# ...
